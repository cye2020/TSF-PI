# %%
import wbdata
import datetime

# %%
wbdata.search_countries('Korea')
# Out:
# id    name
# ----  -------------------------
# KOR   Korea, Rep.
# PRK   Korea, Dem. People's Rep.

# %%
# Set the date range
start_date = datetime.datetime(2000, 1, 1)
end_date = datetime.datetime(2020, 1, 1)

# Fetch GDP data (current US$) for all countries
data = wbdata.get_data("NY.GDP.MKTP.CD", country=('KOR'), data_date=(start_date, end_date))

# %%
data
# Out:
# [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2020',
#   'value': 1644312785467.12,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2019',
#   'value': 1651422932447.77,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2018',
#   'value': 1724845615629.26,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2017',
#   'value': 1623901496835.79,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2016',
#   'value': 1500111596236.37,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2015',
#   'value': 1465773245547.15,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2014',
#   'value': 1484318219633.63,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2013',
#   'value': 1370795199976.18,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2012',
#   'value': 1278427634342.59,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2011',
#   'value': 1253223044718.99,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2010',
#   'value': 1144066965324.49,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2009',
#   'value': 943941876218.743,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2008',
#   'value': 1047339041903.85,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2007',
#   'value': 1172614134912.05,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2006',
#   'value': 1053216892422.02,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2005',
#   'value': 934901101762.491,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2004',
#   'value': 793175007858.066,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2003',
#   'value': 702717332012.991,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2002',
#   'value': 627246081417.004,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2001',
#   'value': 547658231279.87,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'KR', 'value': 'Korea, Rep.'},
#   'countryiso3code': 'KOR',
#   'date': '2000',
#   'value': 576178114168.494,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]
